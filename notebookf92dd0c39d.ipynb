# %% [markdown]
# <a href="https://www.kaggle.com/code/tusher1612/notebookf92dd0c39d?scriptVersionId=283194422" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !git clone https://github.com/tusher1612/my_ai_agent.git
# Out:
# Cloning into 'my_ai_agent'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 57 (delta 20), reused 46 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 35.80 KiB | 3.98 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
